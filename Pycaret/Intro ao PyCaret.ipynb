# %% [markdown]
# # <p style="color:darkblue">Introdução ao PyCaret</p>
#
# <hr>
#
# **Link para abrir no google colab:**
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/TailUFPB/Tutorials/blob/main/Pycaret/Intro ao PyCaret.ipynb)
#
# <hr>
#
# **Link para abrir no deepnote:**
# [![Made withJupyter](https://img.shields.io/badge/Made%20with-Jupyter-orange?style=for-the-badge&logo=Jupyter)](https://beta.deepnote.org/launch?template=data-science&url=https://raw.githubusercontent.com/TailUFPB/Tutorials/blob/main/Pycaret/Intro ao PyCaret.ipynb)
#
# <hr>
#
# * Neste Jupyter-Notebook faremos um breve overview sobre a biblioteca PyCaret, mostrando um pouco sobre como ela é organizada e as vantagens que ela traz.

# %% [markdown]
# ## 1. Quem somos?
# <p align="center">
#     <img src="imgs/tail5.jpg" width="300px">
# </p>
#
# * Somos membros da **TAIL - Technology and Artificial Intelligence League**, a primeira Liga de inteligência artificial e tecnologia do nordeste, sediada na UFPB. Fizemos esse tutorial pra introduzir essa biblioteca, com alguns exemplos práticos.

# %% [markdown]
# ## 2. O que é PyCaret?

# %% [markdown]
# <p align="center">
#    <img src="imgs/PyCaret.png" width="300px">
# </p>

# %% [markdown]
# [PyCaret](https://pycaret.org) é uma biblioteca open source que tem por objetivo **reduzir o trabalho** que as pessoas têm para realizar certas tarefas no universo da Aprendizagem de Máquina. Por exemplo, PyCaret possibilita um ambiente de teste muito mais simples para os que já tem certa experiência e é mais simples e de fácil entendimento para os que não tem tanta experiência com programação ou Aprendizagem de Máquina.

# %% [markdown]
# ## 3. Instalando o PyCaret

# %% [markdown]
# Para instalar o PyCaret, é necessário apenas rodar o código abaixo dentro de seu Jupyter Notebook (local ou Colab)

# %% [markdown]
# ```python
# !pip install PyCaret
# ```

# %% [markdown]
# O PyCaret precisa de python 3.6 ou mais atualizado.

# %% [markdown]
# ### 3.1 Usuários de Colab
# Se você estiver usando Google Colab, você precisará rodar o próximo código no seu notebook para poder ver os gráficos interativos:
# ```python
# from pycaret.utils import enable_colab
# enable_colab()
# ```

# %% [markdown]
# ## 4. Lendo os dados

# %% [markdown]
# Com o Pycaret, podemos ler os dados de duas formas:
# * Usando pandas
# ```python
# import pandas as pd
# data = pd.read_csv("data.csv")
# ```
# * Usando os datasets open source disponibilizados pelo Pycaret
# ```python
# from pycaret.datasets import get_data
# data = get_data('dataset_name')
# ```
#
# Abaixo estão listados os datasets disponibilizados
#
# <hr>
# <table style="background-color: #fdfdfd;" width="770">
# <tbody>
# <tr>
# <td width="107"><strong>Dataset</strong></td>
# <td width="103"><strong>Tipo dos dados</strong></td>
# <td width="171"><strong>Tarefa padrão</strong></td>
# <td width="193"><strong>Variável target</strong></td>
# <td width="102"><strong>Nº de instâncias</strong></td>
# <td width="94"><strong>Nº de atributos</strong></td>
# </tr>
# <tr>
# <td>anomaly</td>
# <td>Multivariate</td>
# <td>Anomaly Detection</td>
# <td>None</td>
# <td>1000</td>
# <td>10</td>
# </tr>
# <tr>
# <td>france</td>
# <td>Multivariate</td>
# <td>Association Rule Mining</td>
# <td>InvoiceNo, Description</td>
# <td>8557</td>
# <td>8</td>
# </tr>
# <tr>
# <td>germany</td>
# <td>Multivariate</td>
# <td>Association Rule Mining</td>
# <td>InvoiceNo, Description</td>
# <td>9495</td>
# <td>8</td>
# </tr>
# <tr>
# <td>bank</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>deposit</td>
# <td>45211</td>
# <td>17</td>
# </tr>
# <tr>
# <td>blood</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>Class</td>
# <td>748</td>
# <td>5</td>
# </tr>
# <tr>
# <td>cancer</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>Class</td>
# <td>683</td>
# <td>10</td>
# </tr>
# <tr>
# <td>credit</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>default</td>
# <td>24000</td>
# <td>24</td>
# </tr>
# <tr>
# <td>diabetes</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>Class variable</td>
# <td>768</td>
# <td>9</td>
# </tr>
# <tr>
# <td>electrical_grid</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>stabf</td>
# <td>10000</td>
# <td>14</td>
# </tr>
# <tr>
# <td>employee</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>left</td>
# <td>14999</td>
# <td>10</td>
# </tr>
# <tr>
# <td>heart</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>DEATH</td>
# <td>200</td>
# <td>16</td>
# </tr>
# <tr>
# <td>heart_disease</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>Disease</td>
# <td>270</td>
# <td>14</td>
# </tr>
# <tr>
# <td>hepatitis</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>Class</td>
# <td>154</td>
# <td>32</td>
# </tr>
# <tr>
# <td>income</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>income &gt;50K</td>
# <td>32561</td>
# <td>14</td>
# </tr>
# <tr>
# <td>juice</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>Purchase</td>
# <td>1070</td>
# <td>15</td>
# </tr>
# <tr>
# <td>nba</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>TARGET_5Yrs</td>
# <td>1340</td>
# <td>21</td>
# </tr>
# <tr>
# <td>wine</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>type</td>
# <td>6498</td>
# <td>13</td>
# </tr>
# <tr>
# <td>telescope</td>
# <td>Multivariate</td>
# <td>Classification (Binary)</td>
# <td>Class</td>
# <td>19020</td>
# <td>11</td>
# </tr>
# <tr>
# <td>glass</td>
# <td>Multivariate</td>
# <td>Classification (Multiclass)</td>
# <td>Type</td>
# <td>214</td>
# <td>10</td>
# </tr>
# <tr>
# <td>iris</td>
# <td>Multivariate</td>
# <td>Classification (Multiclass)</td>
# <td>species</td>
# <td>150</td>
# <td>5</td>
# </tr>
# <tr>
# <td>poker</td>
# <td>Multivariate</td>
# <td>Classification (Multiclass)</td>
# <td>CLASS</td>
# <td>100000</td>
# <td>11</td>
# </tr>
# <tr>
# <td>questions</td>
# <td>Multivariate</td>
# <td>Classification (Multiclass)</td>
# <td>Next_Question</td>
# <td>499</td>
# <td>4</td>
# </tr>
# <tr>
# <td>satellite</td>
# <td>Multivariate</td>
# <td>Classification (Multiclass)</td>
# <td>Class</td>
# <td>6435</td>
# <td>37</td>
# </tr>
# <tr>
# <td>asia_gdp</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>40</td>
# <td>11</td>
# </tr>
# <tr>
# <td>elections</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>3195</td>
# <td>54</td>
# </tr>
# <tr>
# <td>facebook</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>7050</td>
# <td>12</td>
# </tr>
# <tr>
# <td>ipl</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>153</td>
# <td>25</td>
# </tr>
# <tr>
# <td>jewellery</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>505</td>
# <td>4</td>
# </tr>
# <tr>
# <td>mice</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>1080</td>
# <td>82</td>
# </tr>
# <tr>
# <td>migration</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>233</td>
# <td>12</td>
# </tr>
# <tr>
# <td>perfume</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>20</td>
# <td>29</td>
# </tr>
# <tr>
# <td>pokemon</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>800</td>
# <td>13</td>
# </tr>
# <tr>
# <td>population</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>255</td>
# <td>56</td>
# </tr>
# <tr>
# <td>public_health</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>224</td>
# <td>21</td>
# </tr>
# <tr>
# <td>seeds</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>210</td>
# <td>7</td>
# </tr>
# <tr>
# <td>wholesale</td>
# <td>Multivariate</td>
# <td>Clustering</td>
# <td>None</td>
# <td>440</td>
# <td>8</td>
# </tr>
# <tr>
# <td>tweets</td>
# <td>Text</td>
# <td>NLP</td>
# <td>tweet</td>
# <td>8594</td>
# <td>2</td>
# </tr>
# <tr>
# <td>amazon</td>
# <td>Text</td>
# <td>NLP / Classification</td>
# <td>reviewText</td>
# <td>20000</td>
# <td>2</td>
# </tr>
# <tr>
# <td>kiva</td>
# <td>Text</td>
# <td>NLP / Classification</td>
# <td>en</td>
# <td>6818</td>
# <td>7</td>
# </tr>
# <tr>
# <td>spx</td>
# <td>Text</td>
# <td>NLP / Regression</td>
# <td>text</td>
# <td>874</td>
# <td>4</td>
# </tr>
# <tr>
# <td>wikipedia</td>
# <td>Text</td>
# <td>NLP / Classification</td>
# <td>Text</td>
# <td>500</td>
# <td>3</td>
# </tr>
# <tr>
# <td>automobile</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>price</td>
# <td>202</td>
# <td>26</td>
# </tr>
# <tr>
# <td>bike</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>cnt</td>
# <td>17379</td>
# <td>15</td>
# </tr>
# <tr>
# <td>boston</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>medv</td>
# <td>506</td>
# <td>14</td>
# </tr>
# <tr>
# <td>concrete</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>strength</td>
# <td>1030</td>
# <td>9</td>
# </tr>
# <tr>
# <td>diamond</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>Price</td>
# <td>6000</td>
# <td>8</td>
# </tr>
# <tr>
# <td>energy</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>Heating Load / Cooling Load</td>
# <td>768</td>
# <td>10</td>
# </tr>
# <tr>
# <td>forest</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>area</td>
# <td>517</td>
# <td>13</td>
# </tr>
# <tr>
# <td>gold</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>Gold_T+22</td>
# <td>2558</td>
# <td>121</td>
# </tr>
# <tr>
# <td>house</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>SalePrice</td>
# <td>1461</td>
# <td>81</td>
# </tr>
# <tr>
# <td>insurance</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>charges</td>
# <td>1338</td>
# <td>7</td>
# </tr>
# <tr>
# <td>parkinsons</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>PPE</td>
# <td>5875</td>
# <td>22</td>
# </tr>
# <tr>
# <td>traffic</td>
# <td>Multivariate</td>
# <td>Regression</td>
# <td>traffic_volume</td>
# <td>48204</td>
# <td>8</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## 5. Organizando o ambiente
# Antes de executarmos qualquer algoritmo, temos que organizar os dados e importar os módulos necessários para não termos nenhum problem.

# %% [markdown]
# ### 5.1 Importando os Módulos
# O PyCaret é dividido basicamente em 6 módulos que separam os diferentes modelos que podem ser utilizados para determinados problemas.
#
# <table style="height: 199px; width: 532px; background-color: #fdfdfa; border-color: #f9f9f9;">
#     <tbody>
#         <tr style="height: 6.30557px;">
#         <td style="width: 216px; height: 6.30557px;"><strong>Módulo</strong></td>
#         <td style="width: 276px; height: 6.30557px;"><strong>Como importar</strong></td>
#         </tr>
#         <tr style="height: 22px;">
#         <td style="width: 216px; height: 22px;"><a href="https://www.pycaret.org/classification">Classificação</a></td>
#         <td style="width: 276px; height: 22px;"><span style="color: #008000;">from </span>pycaret.classification <span style="color: #008000;">import </span>*</td>
#         </tr>
#         <tr style="height: 22px;">
#         <td style="width: 216px; height: 22px;"><a href="https://www.pycaret.org/regression">Regressão</a></td>
#         <td style="width: 276px; height: 22px;"><span style="color: #008000;">from</span> pycaret.regression <span style="color: #008000;">import </span>*</td>
#         </tr>
#         <tr style="height: 22px;">
#         <td style="width: 216px; height: 22px;"><a href="https://www.pycaret.org/clustering">Clusterização</a></td>
#         <td style="width: 276px; height: 22px;"><span style="color: #008000;">from </span>pycaret.clustering <span style="color: #008000;">import </span>*</td>
#         </tr>
#         <tr style="height: 22px;">
#         <td style="width: 216px; height: 22px;"><a href="https://www.pycaret.org/anomaly-detection">Detecção de Anomalias</a></td>
#         <td style="width: 276px; height: 22px;"><span style="color: #008000;">from </span>pycaret.anomaly <span style="color: #008000;">import </span>*</td>
#         </tr>
#         <tr style="height: 22px;">
#         <td style="width: 216px; height: 22px;"><a href="https://www.pycaret.org/nlp">Processamento de Linguagem Natural</a></td>
#         <td style="width: 276px; height: 22px;"><span style="color: #008000;">from </span>pycaret.nlp <span style="color: #008000;">import</span> *</td>
#         </tr>
#         <tr style="height: 22px;">
#         <td style="width: 216px; height: 22px;"><a href="https://www.pycaret.org/association-rule">Association Rule Mining</a></td>
#         <td style="width: 276px; height: 22px;"><span style="color: #008000;">from </span>pycaret.arules <span style="color: #008000;">import</span> *</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# Exemplo:
#
# ```python
# from pycaret.classification import *
# ```

# %% [markdown]
# ### 5.2 Construindo o ambiente

# %% [markdown]
# Após a importação das funções presentes no módulo desejado, deve-se fazer o setup do ambiente (antes de rodar qualquer função que não a de ler os dados). Vamos executar um pequeno exemplo com o que vimos até então:

# %% [markdown]
# #### 5.2.1 Lendo os dados
#
# Nesse ponto vamos ler um dataset de brinquedo presente no repositório do próprio PyCaret, **satellite**.

# %%
from pycaret.datasets import get_data

data = get_data("satellite")
print("Tamanho do dataset : ", data.shape)
# Out:
#    Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0          80         102         102          79          76         102
# 1          76         102         102          79          76         102
# 2          80          98         106          79          76          94
# 3          76          94         102          76          76          94
# 4          76          94         102          76          76          94
#
#    Attribute7  Attribute8  Attribute9  Attribute10  ...  Attribute28  \
# 0         102          79          76          102  ...           87
# 1         106          83          76          102  ...           87
# 2         102          76          76           94  ...           79
# 3         102          76          76           94  ...           79
# 4         102          76          76           89  ...           75
#
#    Attribute29  Attribute30  Attribute31  Attribute32  Attribute33  \
# 0           79          107          109           87           79
# 1           79          107          113           87           79
# 2           79           95          100           79           79
# 3           79           95           96           75           79
# 4           79           95          100           75           75
#
#    Attribute34  Attribute35  Attribute36  Class
# 0          107          113           87      3
# 1          103          104           83      3
# 2           95           96           75      4
# 3           95          100           75      4
# 4           95          100           79      4
#
# [5 rows x 37 columns]
# Tamanho do dataset :  (6435, 37)

# %% [markdown]
# Nesse dataset, nosso objetivo é performar **uma classificação multiclasse na variável Class**.

# %% [markdown]
# #### 5.2.2 Função setup
#
# A função setup, como dito anteriormente, é essencial para execução dos modelos. Como parâmetros obrigatórios, ela tem **data**, que corresponde ao dataset utilizado, e **target**, que corresponde a variável a ser prevista. Afora esses, ela também possui diversos parâmetros opcionais (você pode ler mais sobre na [**documentação**](https://pycaret.readthedocs.io/en/latest/index.html))

# %%
from pycaret.classification import *

classificador = setup(data = data, target = "Class", train_size=0.8)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_f02e9bb2_1d6a_11eb_828a_a394e194870a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow0_col1" class="data row0 col1" >1939</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow1_col1" class="data row1 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow2_col1" class="data row2 col1" >1: 0, 2: 1, 3: 2, 4: 3, 5: 4, 7: 5</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow3_col1" class="data row3 col1" >(6435, 37)</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow5_col1" class="data row5 col1" >36</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow10_col1" class="data row10 col1" >(6435, 37)</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow11_col1" class="data row11 col1" >(5148, 36)</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow12_col1" class="data row12 col1" >(1287, 36)</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f02e9bb2_1d6a_11eb_828a_a394e194870alevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_f02e9bb2_1d6a_11eb_828a_a394e194870arow18_col1" class="data row18 col1" >

# %% [markdown]
# * Ao rodarmos a célula acima, a função setup identificará os tipos de cada variável e nos retornará um prompt para darmos enter caso esteja correto ou digitarmos **quit**, caso queiramos fazer alguma modificação, se eventualmente houver alguma incoerência com os dados. Para modificar alguma coluna que foi detectada incorretamente, devemos especificar-la nos parâmetros. Se tudo estiver ok, ele printará uma descrição sobre o dataset e o preprocessamento será feito.

# %% [markdown]
# * A função setup também faz a limpeza dos dados. Por padrão, a média é usada para imputação dos dados numéricos (preenchimento dos dados faltantes) e a moda para dados categóricos. Essas configurações podem ser alteradas nos parâmetros da função.

# %% [markdown]
# * Por fim, a função setup também faz a divisão do dataset em treino e teste usando estratificação para exemplos categóricos como o caso acima. O valor padrão de split é 70 treino - 30 teste. Caso deseje mudar é necessário apenas passar o parâmetro adequado na função setup, como fizemos anteriormente.

# %% [markdown]
# ## 6. Comparando modelos

# %% [markdown]
# Nesta secção já vamos começar a rodar nossos **algoritmos de Machine Learning**. Como foi visto, a estrutura do PyCaret é bem simples e, com quase 5 linhas de código, você verá que seremos capazes de rodar 14 algoritmos. :P
#
# Vamos agora ver um pouco como fazer isso. Na função **compare_models()**, todos os algoritmos que podem ser utilizados para resolver o seu problema serão rodados e a função disponibilizará uma tabela com os resultados das métricas e o tempo que levou em segundos. A partir disso o sistema vai fazer o output do modelo que teve o melhor desempenho.

# %%
best_model = compare_models(fold=10, round=3, sort="Accuracy")
# Out:
# <style  type="text/css" >
#     #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8 th {
#           text-align: left;
#     }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col7 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row0_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col7 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row1_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col7 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row2_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col7 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row3_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col7 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row4_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col7 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row5_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col7 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row6_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col0 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col2 {
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_376c6d84_1d29_11eb_9fde_d546d6ff2df8row7_col7 {

# %%
best_model
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#               objective='multi:softprob', random_state=658, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=0)

# %% [markdown]
# É importante ressaltar que você pode mudar a métrica de importância (no parâmetro **sort**). Assim, o modelo retornará o modelo com a melhor peformance nessa métrica. Também é possível retornar mais de um modelo através do parâmetro **n_select**, retirar modelos da lista padrão com **blacklist** e comparar apenas os modelos que você tem interesse com **whitelist**. Além disso, se tempo for uma variável preciosa no trabalho, pode-se setar o parâmetro **turbo=True** para que o compare_models() não execute os algoritmos que demorariam mais tempo.

# %% [markdown]
# ## 7. Criando o modelo

# %% [markdown]
# Vamos criar nosso modelo com a função **create_model()**. Antes disso, vamos observar os modelos que temos disponível através da função **models()**.

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                             Reference  Turbo
# ID
# lr            sklearn.linear_model.LogisticRegression   True
# knn            sklearn.neighbors.KNeighborsClassifier   True
# nb                     sklearn.naive_bayes.GaussianNB   True
# dt                sklearn.tree.DecisionTreeClassifier   True
# svm                sklearn.linear_model.SGDClassifier   True
# rbfsvm                                sklearn.svm.SVC  False
# gpc                      sklearn.gaussian_process.GPC  False
# mlp              sklearn.neural_network.MLPClassifier  False
# ridge            sklearn.linear_model.RidgeClassifier   True
# rf            sklearn.ensemble.RandomForestClassifier   True
# qda                 sklearn.discriminant_analysis.QDA   True
# ada               sklearn.ensemble.AdaBoostClassifier   True
# gbc       sklearn.ensemble.GradientBoostingClassifier   True
# lda                 sklearn.discriminant_analysis.LDA   True
# et              sklearn.ensemble.ExtraTreesClassifier   True
# xgboost                        xgboost.readthedocs.io   True
# lightgbm                github.com/microsoft/LightGBM   True
# catboost                                  catboost.ai   True

# %%
xgboost = create_model("xgboost")
# Out:
# <style  type="text/css" >
#     #T_0a1b61c4_1d69_11eb_828a_a394e194870arow10_col0 {
#             background:  yellow;
#         }    #T_0a1b61c4_1d69_11eb_828a_a394e194870arow10_col1 {
#             background:  yellow;
#         }    #T_0a1b61c4_1d69_11eb_828a_a394e194870arow10_col2 {
#             background:  yellow;
#         }    #T_0a1b61c4_1d69_11eb_828a_a394e194870arow10_col3 {
#             background:  yellow;
#         }    #T_0a1b61c4_1d69_11eb_828a_a394e194870arow10_col4 {
#             background:  yellow;
#         }    #T_0a1b61c4_1d69_11eb_828a_a394e194870arow10_col5 {
#             background:  yellow;
#         }    #T_0a1b61c4_1d69_11eb_828a_a394e194870arow10_col6 {
#             background:  yellow;
#         }</style><table id="T_0a1b61c4_1d69_11eb_828a_a394e194870a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a1b61c4_1d69_11eb_828a_a394e194870alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow0_col0" class="data row0 col0" >0.9165</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow0_col2" class="data row0 col2" >0.8961</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow0_col3" class="data row0 col3" >0.9162</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow0_col4" class="data row0 col4" >0.9152</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow0_col5" class="data row0 col5" >0.8966</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow0_col6" class="data row0 col6" >0.8971</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1b61c4_1d69_11eb_828a_a394e194870alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow1_col0" class="data row1 col0" >0.8971</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow1_col1" class="data row1 col1" >0.0000</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow1_col2" class="data row1 col2" >0.8678</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow1_col3" class="data row1 col3" >0.8948</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow1_col4" class="data row1 col4" >0.8946</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow1_col5" class="data row1 col5" >0.8726</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow1_col6" class="data row1 col6" >0.8731</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1b61c4_1d69_11eb_828a_a394e194870alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow2_col0" class="data row2 col0" >0.9068</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow2_col1" class="data row2 col1" >0.0000</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow2_col2" class="data row2 col2" >0.8905</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow2_col3" class="data row2 col3" >0.9053</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow2_col4" class="data row2 col4" >0.9057</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow2_col5" class="data row2 col5" >0.8847</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow2_col6" class="data row2 col6" >0.8848</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1b61c4_1d69_11eb_828a_a394e194870alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow3_col0" class="data row3 col0" >0.9184</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow3_col1" class="data row3 col1" >0.0000</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow3_col2" class="data row3 col2" >0.8945</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow3_col3" class="data row3 col3" >0.9164</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow3_col4" class="data row3 col4" >0.9165</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow3_col5" class="data row3 col5" >0.8990</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow3_col6" class="data row3 col6" >0.8993</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1b61c4_1d69_11eb_828a_a394e194870alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow4_col0" class="data row4 col0" >0.9049</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow4_col1" class="data row4 col1" >0.0000</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow4_col2" class="data row4 col2" >0.8762</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow4_col3" class="data row4 col3" >0.9019</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow4_col4" class="data row4 col4" >0.9024</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow4_col5" class="data row4 col5" >0.8821</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow4_col6" class="data row4 col6" >0.8824</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1b61c4_1d69_11eb_828a_a394e194870alevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow5_col0" class="data row5 col0" >0.9282</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow5_col1" class="data row5 col1" >0.0000</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow5_col2" class="data row5 col2" >0.9105</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow5_col3" class="data row5 col3" >0.9286</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow5_col4" class="data row5 col4" >0.9274</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow5_col5" class="data row5 col5" >0.9112</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow5_col6" class="data row5 col6" >0.9116</td>
#             </tr>
#             <tr>
#                         <th id="T_0a1b61c4_1d69_11eb_828a_a394e194870alevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow6_col0" class="data row6 col0" >0.8990</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow6_col1" class="data row6 col1" >0.0000</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow6_col2" class="data row6 col2" >0.8757</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow6_col3" class="data row6 col3" >0.8970</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow6_col4" class="data row6 col4" >0.8973</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a394e194870arow6_col5" class="data row6 col5" >0.8752</td>
#                         <td id="T_0a1b61c4_1d69_11eb_828a_a

# %% [markdown]
# Voilá, temos nosso modelo criado :D!!!
#
# Mas será que ele já está bom o suficiente? Vamos dar uma olhada em mais uma etapa que talvez possa nos ajudar a melhorar a performance do nosso modelo.

# %% [markdown]
# ## 8. Tunando o modelo

# %% [markdown]
# Essa etapa é responsável por melhorar nosso modelo escolhido. Aqui passamos parâmetros como:
# * Qual métrica queremos melhorar
# * Quais parâmetros queremos mexer para melhorar essa métrica
# * Número de folds
#
# O PyCaret tem por padrão um grid de parâmetros que ele utiliza para melhorar cada algoritmo. Caso queira fazer o seu próprio, é só elaborar um pequeno dicionário com os parâmetros a serem testados.
# Ex:
# ```python
# params = {"n_estimators": np.random.randint(1, 300, 20),
#           "gamma": [0.1, 0.001, 0.0001],
#           "max_depth": [2,3,4,5,6,10,12]
#          }
# ```
# É claro que para isso é necessário um estudo maior dos hyperparâmetros do algoritmo utilizado.

# %%
params = {
        "n_estimators":[130, 135, 140, 145, 150]
        }

# %%
tuned_xgboost = tune_model(xgboost, fold=5, optimize="Accuracy", custom_grid=params) #vamos usar o default
# Out:
# <style  type="text/css" >
#     #T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col0 {
#             background:  yellow;
#         }    #T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col1 {
#             background:  yellow;
#         }    #T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col2 {
#             background:  yellow;
#         }    #T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col3 {
#             background:  yellow;
#         }    #T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col4 {
#             background:  yellow;
#         }    #T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col5 {
#             background:  yellow;
#         }    #T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col6 {
#             background:  yellow;
#         }</style><table id="T_1e0a864c_1d69_11eb_828a_a394e194870a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e0a864c_1d69_11eb_828a_a394e194870alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow0_col0" class="data row0 col0" >0.9126</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow0_col2" class="data row0 col2" >0.8918</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow0_col3" class="data row0 col3" >0.9116</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow0_col4" class="data row0 col4" >0.9114</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow0_col5" class="data row0 col5" >0.8919</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow0_col6" class="data row0 col6" >0.8922</td>
#             </tr>
#             <tr>
#                         <th id="T_1e0a864c_1d69_11eb_828a_a394e194870alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow1_col0" class="data row1 col0" >0.9087</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow1_col1" class="data row1 col1" >0.0000</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow1_col2" class="data row1 col2" >0.8886</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow1_col3" class="data row1 col3" >0.9070</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow1_col4" class="data row1 col4" >0.9074</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow1_col5" class="data row1 col5" >0.8872</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow1_col6" class="data row1 col6" >0.8873</td>
#             </tr>
#             <tr>
#                         <th id="T_1e0a864c_1d69_11eb_828a_a394e194870alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow2_col0" class="data row2 col0" >0.9117</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow2_col1" class="data row2 col1" >0.0000</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow2_col2" class="data row2 col2" >0.8871</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow2_col3" class="data row2 col3" >0.9095</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow2_col4" class="data row2 col4" >0.9096</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow2_col5" class="data row2 col5" >0.8906</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow2_col6" class="data row2 col6" >0.8909</td>
#             </tr>
#             <tr>
#                         <th id="T_1e0a864c_1d69_11eb_828a_a394e194870alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow3_col0" class="data row3 col0" >0.9067</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow3_col1" class="data row3 col1" >0.0000</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow3_col2" class="data row3 col2" >0.8805</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow3_col3" class="data row3 col3" >0.9039</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow3_col4" class="data row3 col4" >0.9036</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow3_col5" class="data row3 col5" >0.8844</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow3_col6" class="data row3 col6" >0.8850</td>
#             </tr>
#             <tr>
#                         <th id="T_1e0a864c_1d69_11eb_828a_a394e194870alevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow4_col0" class="data row4 col0" >0.9086</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow4_col1" class="data row4 col1" >0.0000</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow4_col2" class="data row4 col2" >0.8915</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow4_col3" class="data row4 col3" >0.9092</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow4_col4" class="data row4 col4" >0.9087</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow4_col5" class="data row4 col5" >0.8873</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow4_col6" class="data row4 col6" >0.8874</td>
#             </tr>
#             <tr>
#                         <th id="T_1e0a864c_1d69_11eb_828a_a394e194870alevel0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col0" class="data row5 col0" >0.9097</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col1" class="data row5 col1" >0.0000</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col2" class="data row5 col2" >0.8879</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col3" class="data row5 col3" >0.9082</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col4" class="data row5 col4" >0.9082</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col5" class="data row5 col5" >0.8883</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow5_col6" class="data row5 col6" >0.8886</td>
#             </tr>
#             <tr>
#                         <th id="T_1e0a864c_1d69_11eb_828a_a394e194870alevel0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow6_col0" class="data row6 col0" >0.0022</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow6_col1" class="data row6 col1" >0.0000</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow6_col2" class="data row6 col2" >0.0041</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow6_col3" class="data row6 col3" >0.0026</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow6_col4" class="data row6 col4" >0.0026</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394e194870arow6_col5" class="data row6 col5" >0.0027</td>
#                         <td id="T_1e0a864c_1d69_11eb_828a_a394

# %%
tuned_xgboost
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=140, n_jobs=-1, num_parallel_tree=1,
#               objective='multi:softprob', random_state=8935, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=0)

# %% [markdown]
# Nesse caso não tivemos um aumento de performance. Teríamos que mexer um pouco mais em nosso grid de parâmetros para melhorar.

# %% [markdown]
# ## 9. Fazendo os plots do nosso modelo

# %% [markdown]
# Com o **plot_model()** podemos plotar os mais diversos gráficos para analisar o desempenho de nosso modelo. A seguir estão mostradas todas as possibilidades.
#
# <table style="height: 100px; width: 422px; border-color: #f9f9f9; background-color: #f9f9f9;" cellspacing="-2" cellpadding="-3">
#     <tbody>
#         <tr>
#         <td style="width: 149px; text-align: center;"><strong>Gráfico</strong></td>
#         <td style="width: 226px; text-align: center;"><strong>Nome</strong></td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘auc’</td>
#         <td style="width: 226px; text-align: center;">Area Under the Curve</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘threshold’</td>
#         <td style="width: 226px; text-align: center;">Discrimination Threshold</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘pr’</td>
#         <td style="width: 226px; text-align: center;">Precision Recall Curve</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘confusion_matrix’</td>
#         <td style="width: 226px; text-align: center;">Confusion Matrix</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘error’</td>
#         <td style="width: 226px; text-align: center;">Class Prediction Error</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘class_report’</td>
#         <td style="width: 226px; text-align: center;">Classification Report</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘boundary’</td>
#         <td style="width: 226px; text-align: center;">Decision Boundary</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘rfe’</td>
#         <td style="width: 226px; text-align: center;">Recursive Feature Selection</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘learning’</td>
#         <td style="width: 226px; text-align: center;">Learning Curve</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘manifold’</td>
#         <td style="width: 226px; text-align: center;">Manifold Learning</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘calibration’</td>
#         <td style="width: 226px; text-align: center;">Calibration Curve</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘vc’</td>
#         <td style="width: 226px; text-align: center;">Validation Curve</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘dimension’</td>
#         <td style="width: 226px; text-align: center;">Dimension Learning</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘feature’</td>
#         <td style="width: 226px; text-align: center;">Feature Importance</td>
#         </tr>
#         <tr>
#         <td style="width: 149px; text-align: center;">‘parameter’</td>
#         <td style="width: 226px; text-align: center;">Model Hyperparameter</td>
#         </tr>
#     </tbody>
# </table>

# %%
plot_model(tuned_xgboost, plot="auc")

# %% [markdown]
# Embora seja bem fácil plotar algum gráfico específico com o PyCaret, é possível plotar todos os gráficos de uma vez e apenas observar de um por um através da interface produzida pelo PyCaret com a função **evaluate_model()**.

# %%
evaluate_model(tuned_xgboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
interpret_model(tuned_xgboost)

# %% [markdown]
# ## 10. Acessando as variáveis

# %% [markdown]
# O PyCaret, como pudemos observar até então, é a verdadeira definição de caixa preta haha. Contudo, podemos ter acesso às variáveis com a função **get_config(Variable)**. Essa função retornará um objeto diferente de acordo com a string que você passar. A seguir são os possíveis objetos que podemos ter acesso:
#
# <ul>
#     <li>X: Transformed dataset (X)</li>
#     <li>y: Transformed dataset (y)&nbsp;&nbsp;</li>
#     <li>X_train: Transformed train dataset (X)</li>
#     <li>X_test: Transformed test/holdout dataset (X)</li>
#     <li>y_train: Transformed train dataset (y)</li>
#     <li>y_test: Transformed test/holdout dataset (y)</li>
#     <li>seed: random state set through session_id</li>
#     <li>prep_pipe: Transformation pipeline configured through setup</li>
#     <li>folds_shuffle_param: shuffle parameter used in Kfolds</li>
#     <li>n_jobs_param: n_jobs parameter used in model training</li>
#     <li>html_param: html_param configured through setup</li>
#     <li>create_model_container: results grid storage container</li>
#     <li>master_model_container: model storage container</li>
#     <li>display_container: results display container</li>
#     <li>exp_name_log: Name of experiment set through setup</li>
#     <li>logging_param: log_experiment param set through setup</li>
#     <li>log_plots_param: log_plots param set through setup</li>
#     <li>USI: Unique session ID parameter set through setup</li>
#     <li>fix_imbalance_param: fix_imbalance param set through setup</li>
#     <li>fix_imbalance_method_param: fix_imbalance_method param set through setup</li>
# </ul>

# %% [markdown]
# **Ex:**

# %%
X_test = get_config("X_test")
X_test.head()
# Out:
#       Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 2659        46.0        34.0       124.0       124.0        46.0        37.0
# 4919        75.0        99.0       101.0        79.0        67.0        99.0
# 2305        87.0        99.0       105.0        83.0        83.0       103.0
# 556         48.0        37.0       118.0       121.0        48.0        34.0
# 1864        86.0       104.0       108.0        81.0        86.0        96.0
#
#       Attribute7  Attribute8  Attribute9  Attribute10  ...  Attribute27  \
# 2659       119.0       127.0        46.0         37.0  ...        120.0
# 4919       110.0        86.0        71.0        112.0  ...        102.0
# 2305       105.0        86.0        83.0        103.0  ...        102.0
# 556        118.0       121.0        48.0         34.0  ...        124.0
# 1864       104.0        81.0        82.0         96.0  ...         97.0
#
#       Attribute28  Attribute29  Attribute30  Attribute31  Attribute32  \
# 2659        120.0         47.0         37.0        120.0        124.0
# 4919         79.0         60.0         85.0         94.0         79.0
# 2305         83.0         80.0         98.0         98.0         79.0
# 556         131.0         46.0         32.0        124.0        139.0
# 1864         76.0         82.0         97.0         97.0         80.0
#
#       Attribute33  Attribute34  Attribute35  Attribute36
# 2659         44.0         37.0        120.0        124.0
# 4919         64.0         89.0         98.0         83.0
# 2305         84.0         98.0        106.0         83.0
# 556          46.0         30.0        119.0        131.0
# 1864         85.0         97.0         97.0         80.0
#
# [5 rows x 36 columns]

# %% [markdown]
# ## 11. Prevendo com nosso modelo

# %%
predict_model(model)
# Out:
#                        Model  Accuracy  AUC  Recall  Prec.     F1   Kappa  \
# 0  Extreme Gradient Boosting    0.9285    0  0.9077  0.927  0.927  0.9116
#
#       MCC
# 0  0.9119
#       Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0           46.0        34.0       124.0       124.0        46.0        37.0
# 1           75.0        99.0       101.0        79.0        67.0        99.0
# 2           87.0        99.0       105.0        83.0        83.0       103.0
# 3           48.0        37.0       118.0       121.0        48.0        34.0
# 4           86.0       104.0       108.0        81.0        86.0        96.0
# ...          ...         ...         ...         ...         ...         ...
# 1282        74.0        83.0        88.0        66.0        66.0        75.0
# 1283        59.0        51.0        65.0        45.0        59.0        54.0
# 1284        86.0       109.0       108.0        89.0        86.0       104.0
# 1285        52.0        37.0       117.0       122.0        46.0        29.0
# 1286        74.0       106.0       124.0       104.0        78.0       111.0
#
#       Attribute7  Attribute8  Attribute9  Attribute10  ...  Attribute30  \
# 0          119.0       127.0        46.0         37.0  ...         37.0
# 1          110.0        86.0        71.0        112.0  ...         85.0
# 2          105.0        86.0        83.0        103.0  ...         98.0
# 3          118.0       121.0        48.0         34.0  ...         32.0
# 4          104.0        81.0        82.0         96.0  ...         97.0
# ...          ...         ...         ...          ...  ...          ...
# 1282        76.0        55.0        63.0         71.0  ...         84.0
# 1283        62.0        45.0        59.0         57.0  ...         55.0
# 1284       108.0        85.0        86.0        104.0  ...        106.0
# 1285       138.0       151.0        49.0         32.0  ...         43.0
# 1286       129.0       101.0        67.0        102.0  ...        107.0
#
#       Attribute31  Attribute32  Attribute33  Attribute34  Attribute35  \
# 0           120.0        124.0         44.0         37.0        120.0
# 1            94.0         79.0         64.0         89.0         98.0
# 2            98.0         79.0         84.0         98.0        106.0
# 3           124.0        139.0         46.0         30.0        119.0
# 4            97.0         80.0         85.0         97.0         97.0
# ...           ...          ...          ...          ...          ...
# 1282         82.0         58.0         67.0         79.0         82.0
# 1283         67.0         54.0         53.0         49.0         64.0
# 1284        114.0         90.0         89.0        106.0        114.0
# 1285        110.0        115.0         44.0         34.0        129.0
# 1286        122.0        103.0         71.0        112.0        122.0
#
#       Attribute36  Class  Label   Score
# 0           124.0      2      2  1.0000
# 1            83.0      1      1  0.9992
# 2            83.0      3      3  0.9492
# 3           131.0      2      2  1.0000
# 4            80.0      3      4  0.9555
# ...           ...    ...    ...     ...
# 1282         62.0      7      7  0.9999
# 1283         50.0      5      5  0.9999
# 1284         87.0      3      3  0.9802
# 1285        143.0      2      2  1.0000
# 1286         99.0      1      1  1.0000
#
# [1287 rows x 39 columns]

# %% [markdown]
# Como vemos acima, a função predict_model nos retorna as métricas correspondentes à previsão, além de retornar junto ao DataFrame original uma coluna **Label**, que equivale ao que o modelo preveu.

# %% [markdown]
# Também é possível prever um novo conjunto passando como parâmetro da seguinte forma:
# ```python
# predict_model(model, data = novos_dados)
# ```

# %% [markdown]
# ## 12. Finalizando o modelo

# %% [markdown]
# Por finalizar o modelo, temos como objetivo juntar os dados de teste aos de treinamento e fazer um modelo baseado em todos os dados para ir para produção.

# %%
finalize_model(tuned_xgboost)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=140, n_jobs=-1, num_parallel_tree=1,
#               objective='multi:softprob', random_state=8935, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=0)

# %% [markdown]
# ## 13. Salvando e carregando o modelo

# %%
save_model(tuned_xgboost, "xgboost_model")
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# A função **save_model()** salva não apenas o modelo, mas o pipeline de preprocessamento que foi construído na função **setup()**

# %%
model = load_model("xgboost_model")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ## Próximos passos : Fazendo o Deploy de um modelo

# %% [markdown]
# **Referências**:
# * https://pycaret.org/classification/
# * https://pycaret.org/preprocessing/
# * https://pycaret.readthedocs.io/en/latest/index.html
# * https://pycaret.org/compare-models/
# * https://github.com/pycaret/pycaret/tree/master/tutorials
